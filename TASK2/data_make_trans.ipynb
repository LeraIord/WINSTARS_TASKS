# %%
import os
import csv

# %% [markdown]
# Creating the dataset

# %%
data = [
    # ------------------ DOG (100) ------------------
    ("I saw a dog running across the field.", "dog"),
    ("The dog barked at the passing car.", "dog"),
    ("My neighbor's dog is very friendly.", "dog"),
    ("We adopted a dog from the local shelter.", "dog"),
    ("The dog wagged its tail happily.", "dog"),
    ("A stray dog was looking for food.", "dog"),
    ("Do you see that dog by the tree?", "dog"),
    ("A big black dog guarded the house.", "dog"),
    ("That dog's fur is so soft.", "dog"),
    ("A police dog helped find the missing child.", "dog"),
    ("The dog chased the squirrel in the yard.", "dog"),
    ("My best friend owns a playful dog.", "dog"),
    ("Have you fed the dog yet?", "dog"),
    ("I took my dog for a walk along the beach.", "dog"),
    ("The dog jumped into the water without hesitation.", "dog"),
    ("A little white dog barked at me this morning.", "dog"),
    ("She trains her dog to do tricks.", "dog"),
    ("The dog was sleeping on the couch.", "dog"),
    ("You can hear the dog howling at night.", "dog"),
    ("A search-and-rescue dog saved several hikers.", "dog"),
    ("I found a lost dog wandering on my street.", "dog"),
    ("That dog has a collar with its name on it.", "dog"),
    ("My brother loves playing fetch with his dog.", "dog"),
    ("A dog can be a loyal companion.", "dog"),
    ("Have you ever seen such a huge dog before?", "dog"),
    ("The dog followed us home.", "dog"),
    ("I took the dog to the vet for a check-up.", "dog"),
    ("The dog's tail wagged vigorously.", "dog"),
    ("They named their new dog Lucky.", "dog"),
    ("The neighbor's dog barked at the mailman.", "dog"),
    ("A guide dog can help a visually impaired person.", "dog"),
    ("I've always wanted a dog of my own.", "dog"),
    ("The dog rolled over for a belly rub.", "dog"),
    ("My cousin's dog is afraid of thunderstorms.", "dog"),
    ("She gave her dog a bath in the backyard.", "dog"),
    ("A dog can sense people's emotions.", "dog"),
    ("The dog stared at me with big brown eyes.", "dog"),
    ("Our dog loves to chase tennis balls.", "dog"),
    ("The dog was trained to detect contraband.", "dog"),
    ("My sister's dog is named Bella.", "dog"),
    ("The dog barked at the cat next door.", "dog"),
    ("Walking the dog is part of my daily routine.", "dog"),
    ("The dog's owner forgot to close the gate.", "dog"),
    ("This dog breed is known for its intelligence.", "dog"),
    ("The dog jumped up to greet me.", "dog"),
    ("A well-trained dog won't bark excessively.", "dog"),
    ("Dogs can learn many commands quickly.", "dog"),
    ("The dog's fur was covered in mud.", "dog"),
    ("We rescued an abandoned dog last week.", "dog"),
    ("A therapy dog can comfort patients.", "dog"),
    ("The dog sniffed around the garden.", "dog"),
    ("She taught her dog to ring a bell when hungry.", "dog"),
    ("A small dog was curled up in a corner.", "dog"),
    ("He whistled and the dog came running.", "dog"),
    ("The dog growled at the stranger.", "dog"),
    ("They took the dog to obedience school.", "dog"),
    ("Our dog chewed my favorite slippers.", "dog"),
    ("The dog's ears perked up at the sound.", "dog"),
    ("That lost dog must be scared and hungry.", "dog"),
    ("It's amazing how loyal a dog can be.", "dog"),
    ("The dog guarded the house while we were away.", "dog"),
    ("There's a dog barking in the distance.", "dog"),
    ("We bought a new toy for our dog.", "dog"),
    ("The dog was panting after running around.", "dog"),
    ("Our dog loves car rides.", "dog"),
    ("This dog breed is known for its speed.", "dog"),
    ("The dog jumped over the fence.", "dog"),
    ("His dog always sleeps at the foot of his bed.", "dog"),
    ("I saw a cute dog at the pet store.", "dog"),
    ("The dog's collar has a shiny tag.", "dog"),
    ("Have you ever groomed a dog before?", "dog"),
    ("The dog barked excitedly when I arrived.", "dog"),
    ("My aunt's dog can open doors.", "dog"),
    ("Look at that dog chasing a butterfly!", "dog"),
    ("The dog was patiently waiting by the door.", "dog"),
    ("My father trained his dog to fetch the newspaper.", "dog"),
    ("The dog's paws left muddy footprints.", "dog"),
    ("A hunting dog must be well-trained.", "dog"),
    ("The dog got lost in the woods.", "dog"),
    ("My mother scolded the dog for digging holes.", "dog"),
    ("A faithful dog will stay by your side.", "dog"),
    ("The dog perched on the couch to watch outside.", "dog"),
    ("In some countries, a dog must be microchipped.", "dog"),
    ("Our dog howls whenever an ambulance passes.", "dog"),
    ("The dog protected the children in the yard.", "dog"),
    ("My grandmother's dog is very old.", "dog"),
    ("We found a collarless dog wandering the park.", "dog"),
    ("The dog's bark echoed through the neighborhood.", "dog"),
    ("She sang a lullaby to calm her dog.", "dog"),
    ("The dog rummaged through the trash can.", "dog"),
    ("He set out a bowl of water for the thirsty dog.", "dog"),
    ("The dog's playful antics made us laugh.", "dog"),
    ("I taught my dog how to roll over in a day.", "dog"),
    ("Her dog always greets her at the door.", "dog"),
    ("The dog circled around before lying down.", "dog"),
    ("We took the dog to the beach to play fetch.", "dog"),
    ("My friend's dog is scared of fireworks.", "dog"),
    ("The dog was fascinated by its own reflection.", "dog"),
    ("A dog's sense of smell is incredibly strong.", "dog"),
    ("The dog barked joyfully when I mentioned 'treat.'", "dog"),

    # ------------------ HORSE (100) ------------------
    ("I went riding on a horse last weekend.", "horse"),
    ("That horse galloped gracefully across the field.", "horse"),
    ("My cousin owns a horse named Thunder.", "horse"),
    ("You can see the horse resting under the tree.", "horse"),
    ("The horse neighed loudly in the stable.", "horse"),
    ("A wild horse roamed freely in the valley.", "horse"),
    ("She brushed the horse's mane carefully.", "horse"),
    ("This horse is known for its speed and agility.", "horse"),
    ("The horse drank water from the trough.", "horse"),
    ("I've never seen a horse so tall.", "horse"),
    ("The rider guided the horse gently.", "horse"),
    ("The horse jumped over the fence with ease.", "horse"),
    ("A horse can be an excellent companion.", "horse"),
    ("My friend competes in horse jumping events.", "horse"),
    ("The horse trotted around the arena.", "horse"),
    ("That horse has a shiny black coat.", "horse"),
    ("We fed the horse some carrots and apples.", "horse"),
    ("Her horse is trained for dressage competitions.", "horse"),
    ("A horse can live for over two decades.", "horse"),
    ("They rode the horse along the beach at sunset.", "horse"),
    ("My uncle raises a special breed of horse.", "horse"),
    ("She learned how to mount a horse properly.", "horse"),
    ("He whispered softly to calm the horse.", "horse"),
    ("The horse followed its rider obediently.", "horse"),
    ("A frightened horse can be dangerous.", "horse"),
    ("I saw a horse race on TV last night.", "horse"),
    ("The horse's tail swished to keep flies away.", "horse"),
    ("She braided the horse's mane before the show.", "horse"),
    ("A horse stable needs regular cleaning.", "horse"),
    ("This horse is famous for winning many races.", "horse"),
    ("I watched a horse-drawn carriage go by.", "horse"),
    ("The horse nuzzled my hand looking for treats.", "horse"),
    ("A ranch usually has more than one horse.", "horse"),
    ("He carefully examined the horse's hooves.", "horse"),
    ("I plan to visit a horse farm this summer.", "horse"),
    ("The horse trotted calmly beside me.", "horse"),
    ("A gentle horse is perfect for beginner riders.", "horse"),
    ("We put a blanket over the horse in winter.", "horse"),
    ("The horse's coat shone in the sunlight.", "horse"),
    ("She taught the horse to bow on command.", "horse"),
    ("A thoroughbred horse is often used in racing.", "horse"),
    ("We admired the horse from a safe distance.", "horse"),
    ("The horse cantered around the open field.", "horse"),
    ("I heard a horse whinny near the barn.", "horse"),
    ("The horse trainer was very experienced.", "horse"),
    ("A sturdy horse can carry heavy loads.", "horse"),
    ("I once got kicked by a horse accidentally.", "horse"),
    ("He gently stroked the horse's neck.", "horse"),
    ("We rode a horse through the forest trail.", "horse"),
    ("The horse recognized its owner immediately.", "horse"),
    ("A pregnant horse needs extra care.", "horse"),
    ("That show horse has won many awards.", "horse"),
    ("Horses often sleep standing up.", "horse"),
    ("I love the smell of hay in the horse barn.", "horse"),
    ("The horse was startled by a sudden noise.", "horse"),
    ("They led the horse to the starting gate.", "horse"),
    ("She praised the horse after a good performance.", "horse"),
    ("A retired racehorse can still be a great pet.", "horse"),
    ("The horse gently nudged me with its muzzle.", "horse"),
    ("We watched a horse demonstration at the fair.", "horse"),
    ("He placed a saddle on the horse's back.", "horse"),
    ("A miniature horse is surprisingly small.", "horse"),
    ("The horse stamped its hoof impatiently.", "horse"),
    ("She guided the horse in a circular pen.", "horse"),
    ("He competes in horse polo matches.", "horse"),
    ("This horse breed is known for endurance.", "horse"),
    ("She entered her horse in a local competition.", "horse"),
    ("A stable boy feeds and waters the horse daily.", "horse"),
    ("My dream is to own a horse ranch someday.", "horse"),
    ("He dismounted the horse with ease.", "horse"),
    ("A well-trained horse responds to subtle cues.", "horse"),
    ("The horse snorted and tossed its head.", "horse"),
    ("She visited the horse every morning.", "horse"),
    ("The horse walked slowly on the trail.", "horse"),
    ("A blacksmith was called to shoe the horse.", "horse"),
    ("They used a horse to pull the carriage.", "horse"),
    ("That horse has a white stripe on its face.", "horse"),
    ("He guided the horse around the barrels.", "horse"),
    ("The horse refused to cross the small stream.", "horse"),
    ("She gave her horse a sugar cube as a reward.", "horse"),
    ("Horses can communicate through body language.", "horse"),
    ("He admired the horse's muscular build.", "horse"),
    ("She competes in horse dressage events weekly.", "horse"),
    ("The horse whinnied when it saw its companion.", "horse"),
    ("A horse's sense of smell is quite good.", "horse"),
    ("We watched the horse show from the bleachers.", "horse"),
    ("This ranch has a famous stallion horse.", "horse"),
    ("He groomed the horse meticulously before the parade.", "horse"),
    ("The horse reared up when frightened.", "horse"),
    ("She's learning to harness the horse for a cart.", "horse"),
    ("I took a photo of the horse in the meadow.", "horse"),
    ("A wild horse can be difficult to approach.", "horse"),
    ("She uses a gentle approach to train the horse.", "horse"),
    ("He always wears a helmet when riding his horse.", "horse"),
    ("The horse drank from a clear stream.", "horse"),
    ("She rinsed the mud off the horse's legs.", "horse"),
    ("He carefully led the horse into the trailer.", "horse"),
    ("A horse can be quite affectionate to its caretaker.", "horse"),
    ("The horse flicked its ears at the sound of thunder.", "horse"),
    ("We watched the horse vanish into the rolling hills.", "horse"),

    # ------------------ ELEPHANT (100) ------------------
    ("An elephant can weigh several tons.", "elephant"),
    ("We saw an elephant at the safari park.", "elephant"),
    ("The elephant used its trunk to grab some leaves.", "elephant"),
    ("A baby elephant is called a calf.", "elephant"),
    ("The elephant trumpeted loudly in the distance.", "elephant"),
    ("An elephant's ears help it regulate body temperature.", "elephant"),
    ("We watched the elephant take a mud bath.", "elephant"),
    ("The elephant walked slowly through the grasslands.", "elephant"),
    ("Elephants are known for their intelligence.", "elephant"),
    ("He fed the elephant a bunch of bananas.", "elephant"),
    ("An elephant's trunk has many muscles.", "elephant"),
    ("The elephant herd gathered around a waterhole.", "elephant"),
    ("This zoo has a large African elephant exhibit.", "elephant"),
    ("An elephant never forgets, or so they say.", "elephant"),
    ("We observed an elephant spraying water on its back.", "elephant"),
    ("The elephant gently lifted a log with its trunk.", "elephant"),
    ("An elephant can live for more than 60 years.", "elephant"),
    ("The elephant's tusks can grow very long.", "elephant"),
    ("I saw an elephant painting a picture once.", "elephant"),
    ("A baby elephant stayed close to its mother.", "elephant"),
    ("The elephant knocked down a small tree.", "elephant"),
    ("Many tourists came to see the elephant show.", "elephant"),
    ("Elephants communicate with low-frequency rumbles.", "elephant"),
    ("We must protect the elephant from poachers.", "elephant"),
    ("An elephant can consume a massive amount of food daily.", "elephant"),
    ("The elephant flapped its big ears.", "elephant"),
    ("He took photos of the elephant in the wild.", "elephant"),
    ("Some cultures regard the elephant as sacred.", "elephant"),
    ("The elephant seemed calm and peaceful.", "elephant"),
    ("An elephant's trunk is incredibly versatile.", "elephant"),
    ("We observed the elephant shaking branches to get leaves.", "elephant"),
    ("That elephant took a long drink from the pond.", "elephant"),
    ("He rode on an elephant during his trip to Thailand.", "elephant"),
    ("The circus used to feature an elephant act.", "elephant"),
    ("An elephant can smell water from miles away.", "elephant"),
    ("We watched the elephant carefully cross the river.", "elephant"),
    ("Elephants often gather in matriarchal herds.", "elephant"),
    ("The elephant raised its trunk to greet us.", "elephant"),
    ("A group of elephants is called a parade or herd.", "elephant"),
    ("She donated to an elephant conservation charity.", "elephant"),
    ("An elephant's memory is quite remarkable.", "elephant"),
    ("We heard the elephant's trumpet echo across the savannah.", "elephant"),
    ("The elephant rubbed against a large boulder.", "elephant"),
    ("A mother elephant fiercely protects her calf.", "elephant"),
    ("The elephant slowly lumbered along the path.", "elephant"),
    ("He was amazed by the elephant's enormous footprint.", "elephant"),
    ("The elephant swayed its trunk back and forth.", "elephant"),
    ("We watched an elephant display surprising dexterity.", "elephant"),
    ("An elephant can use branches as tools.", "elephant"),
    ("The elephant dusted itself with sand to keep cool.", "elephant"),
    ("They tracked the elephant's movements through GPS.", "elephant"),
    ("The elephant roamed freely in the national park.", "elephant"),
    ("He was startled by the elephant's sudden charge.", "elephant"),
    ("We saw an elephant playing with its companions.", "elephant"),
    ("An elephant can show empathy to other elephants.", "elephant"),
    ("The elephant's thick skin protects it from the sun.", "elephant"),
    ("We encountered a wild elephant on the safari.", "elephant"),
    ("She once bathed an elephant at a sanctuary.", "elephant"),
    ("The elephant reached high to pluck fruit from a branch.", "elephant"),
    ("Elephants can recognize themselves in mirrors.", "elephant"),
    ("A male elephant is called a bull.", "elephant"),
    ("I read about an elephant rescue mission.", "elephant"),
    ("The elephant approached cautiously but curiously.", "elephant"),
    ("Conservationists work to protect the elephant habitat.", "elephant"),
    ("He watched the elephant tear off bark with its tusks.", "elephant"),
    ("An elephant's trunk can sense tiny objects.", "elephant"),
    ("The elephant seemed to mourn its lost friend.", "elephant"),
    ("She saw an albino elephant in a documentary.", "elephant"),
    ("Elephants can travel great distances for water.", "elephant"),
    ("The baby elephant stumbled but quickly got up.", "elephant"),
    ("We helped fund an elephant orphanage in Kenya.", "elephant"),
    ("The elephant rocked gently from side to side.", "elephant"),
    ("An elephant's social bonds are very strong.", "elephant"),
    ("He studied the elephant footprints to track them.", "elephant"),
    ("That elephant could pick up a coin with its trunk.", "elephant"),
    ("Poachers target the elephant for its ivory tusks.", "elephant"),
    ("She admired the elephant's massive presence.", "elephant"),
    ("The elephant let out a loud trumpet to warn us.", "elephant"),
    ("We spotted a solitary elephant near the riverbank.", "elephant"),
    ("Some elephants have smaller tusks than others.", "elephant"),
    ("Elephants often show signs of grief and compassion.", "elephant"),
    ("I watched a nature program about elephant migration.", "elephant"),
    ("The elephant smashed a watermelon easily.", "elephant"),
    ("A bull elephant can be aggressive during musth.", "elephant"),
    ("We saw an elephant crossing the dirt road ahead.", "elephant"),
    ("Elephants can communicate through vibrations in the ground.", "elephant"),
    ("She spent hours observing the elephant herd dynamics.", "elephant"),
    ("The orphaned elephant was adopted by a sanctuary.", "elephant"),
    ("The elephant used its trunk to trumpet loudly.", "elephant"),
    ("He was fascinated by the elephant's thick eyelashes.", "elephant"),
    ("Elephants are known to help other injured elephants.", "elephant"),
    ("The elephant's skin looked wrinkled and gray.", "elephant"),
    ("We took refuge behind a tree when the elephant charged.", "elephant"),
    ("He volunteered at an elephant rehabilitation center.", "elephant"),
    ("An elephant can carry heavy logs with its trunk.", "elephant"),
    ("The elephant carefully avoided stepping on the young calf.", "elephant"),
    ("Hunters once threatened the elephant population severely.", "elephant"),
    ("The elephant's intelligence rivals that of primates.", "elephant"),
    ("We saw the elephant flinging dust onto its back.", "elephant"),
    ("A peaceful elephant approached us without fear.", "elephant"),

    # ------------------ BUTTERFLY (100) ------------------
    ("A butterfly landed on my shoulder today.", "butterfly"),
    ("The garden was filled with butterfly species.", "butterfly"),
    ("A butterfly emerges from a chrysalis.", "butterfly"),
    ("That colorful butterfly caught my eye.", "butterfly"),
    ("We watched the butterfly flutter among the flowers.", "butterfly"),
    ("A monarch butterfly migrates thousands of miles.", "butterfly"),
    ("She tried to photograph a rare butterfly in the wild.", "butterfly"),
    ("A butterfly's wings can feature intricate patterns.", "butterfly"),
    ("The butterfly exhibit at the museum was amazing.", "butterfly"),
    ("I saw a bright blue butterfly near the pond.", "butterfly"),
    ("A butterfly symbolizes transformation.", "butterfly"),
    ("She gently cupped her hands around a butterfly.", "butterfly"),
    ("The butterfly perched on a red rose.", "butterfly"),
    ("He identified the butterfly as a swallowtail.", "butterfly"),
    ("A butterfly's lifespan can be quite short.", "butterfly"),
    ("The butterfly garden attracts many visitors.", "butterfly"),
    ("We planted flowers to attract the butterfly population.", "butterfly"),
    ("The delicate butterfly sipped nectar from a blossom.", "butterfly"),
    ("That butterfly has striking black and yellow markings.", "butterfly"),
    ("A butterfly can be surprisingly fast in flight.", "butterfly"),
    ("She drew a beautiful butterfly in her sketchbook.", "butterfly"),
    ("He studied the butterfly's wing structure.", "butterfly"),
    ("We spotted a butterfly dancing in the sunlight.", "butterfly"),
    ("A caterpillar eventually transforms into a butterfly.", "butterfly"),
    ("A butterfly can help pollinate certain plants.", "butterfly"),
    ("He gently moved the butterfly to a safer spot.", "butterfly"),
    ("A group of butterfly enthusiasts visited the forest.", "butterfly"),
    ("A butterfly's wings are fragile but resilient.", "butterfly"),
    ("We observed a butterfly slowly opening and closing its wings.", "butterfly"),
    ("She read a book about the butterfly life cycle.", "butterfly"),
    ("That butterfly is known to migrate every year.", "butterfly"),
    ("He admired the butterfly perched on a leaf.", "butterfly"),
    ("A butterfly festival is held each spring.", "butterfly"),
    ("The butterfly soared gracefully in the breeze.", "butterfly"),
    ("She tried to paint a realistic butterfly mural.", "butterfly"),
    ("A butterfly flitted from one flower to another.", "butterfly"),
    ("I found a butterfly resting on my windowsill.", "butterfly"),
    ("He recognized the butterfly species by its spots.", "butterfly"),
    ("A butterfly house is a lovely place to visit.", "butterfly"),
    ("The butterfly's vibrant colors were breathtaking.", "butterfly"),
    ("She carefully took a photo of the butterfly's patterned wings.", "butterfly"),
    ("We learned about the butterfly's metamorphosis in class.", "butterfly"),
    ("A butterfly can camouflage itself from predators.", "butterfly"),
    ("This region is home to a rare butterfly species.", "butterfly"),
    ("She noticed a tiny butterfly on the garden bench.", "butterfly"),
    ("He caught a glimpse of a butterfly in the meadow.", "butterfly"),
    ("A butterfly on a flower makes a perfect picture.", "butterfly"),
    ("She gently observed the butterfly's antennae.", "butterfly"),
    ("The butterfly appeared to dance in the sunlight.", "butterfly"),
    ("He followed the butterfly deeper into the garden.", "butterfly"),
    ("A vibrant orange butterfly crossed our path.", "butterfly"),
    ("She held out her finger and the butterfly landed on it.", "butterfly"),
    ("The butterfly exhibit showcased exotic species.", "butterfly"),
    ("He discovered a new butterfly species during his expedition.", "butterfly"),
    ("A butterfly's wings might appear iridescent.", "butterfly"),
    ("She was mesmerized by the butterfly's delicate flight.", "butterfly"),
    ("We saw a cluster of butterfly cocoons hanging from a branch.", "butterfly"),
    ("A butterfly soared high above the treetops.", "butterfly"),
    ("The butterfly disappeared into the flowerbed.", "butterfly"),
    ("He teaches a course on butterfly conservation.", "butterfly"),
    ("A butterfly can sometimes be mistaken for a moth.", "butterfly"),
    ("The butterfly flapped its wings slowly to warm up.", "butterfly"),
    ("A sudden gust of wind carried the butterfly away.", "butterfly"),
    ("She discovered a rare butterfly in her backyard.", "butterfly"),
    ("He gently scooped the butterfly off the sidewalk.", "butterfly"),
    ("A butterfly often emerges in the morning sunlight.", "butterfly"),
    ("We marveled at the butterfly's radiant colors.", "butterfly"),
    ("Butterflies add beauty to any garden.", "butterfly"),
    ("She found a butterfly resting on the windowsill, waiting for dawn.", "butterfly"),
    ("He traced the butterfly's pattern in his notebook.", "butterfly"),
    ("A butterfly is a symbol of hope in many cultures.", "butterfly"),
    ("We spotted a butterfly sipping nectar from a dandelion.", "butterfly"),
    ("Her favorite necklace features a butterfly pendant.", "butterfly"),
    ("The butterfly soared above the blooming lavender.", "butterfly"),
    ("A butterfly migration is a wonderful spectacle.", "butterfly"),
    ("He carefully approached the butterfly for a closer look.", "butterfly"),
    ("The butterfly quivered its wings before takeoff.", "butterfly"),
    ("We visited a conservation area for butterfly protection.", "butterfly"),
    ("A butterfly can detect scents with its antennae.", "butterfly"),
    ("She watched a butterfly lay eggs on a leaf.", "butterfly"),
    ("The children squealed with delight at the butterfly release.", "butterfly"),
    ("He saw a white butterfly floating near the fence.", "butterfly"),
    ("A butterfly can sense the sweetness of a flower.", "butterfly"),
    ("She spent hours photographing a rare butterfly species.", "butterfly"),
    ("The butterfly fluttered around our picnic blanket.", "butterfly"),
    ("We gently encouraged the butterfly to fly away safely.", "butterfly"),
    ("A blue butterfly is a sign of joy for some people.", "butterfly"),
    ("He rescued a butterfly stuck in a spider web.", "butterfly"),
    ("The butterfly gracefully avoided nearby predators.", "butterfly"),
    ("She wrote a poem about a butterfly's journey.", "butterfly"),
    ("A butterfly feeding station can attract many species.", "butterfly"),
    ("He collected data on butterfly populations for research.", "butterfly"),
    ("The butterfly's eyes are made up of tiny lenses.", "butterfly"),
    ("She observed the butterfly's unique spots and stripes.", "butterfly"),
    ("A butterfly can be a pollinator for wildflowers.", "butterfly"),
    ("We saw a beautiful butterfly resting on a rock.", "butterfly"),
    ("He was delighted when the butterfly landed on his hat.", "butterfly"),
    ("A butterfly sometimes imitates leaves for camouflage.", "butterfly"),
    ("We carefully watched a butterfly drying its new wings.", "butterfly"),
    ("A butterfly release ceremony can be symbolic at weddings.", "butterfly"),

    # ------------------ CHICKEN (100) ------------------
    ("We keep a chicken coop in our backyard.", "chicken"),
    ("The chicken clucked softly in the morning.", "chicken"),
    ("My grandma raises a chicken for fresh eggs.", "chicken"),
    ("A chicken can lay an egg almost every day.", "chicken"),
    ("We heard the chicken scratching the ground for food.", "chicken"),
    ("That chicken has beautiful brown feathers.", "chicken"),
    ("A chicken ran across the road unexpectedly.", "chicken"),
    ("He fed the chicken some corn kernels.", "chicken"),
    ("The chicken roosted on a wooden perch.", "chicken"),
    ("She collected eggs from the chicken coop.", "chicken"),
    ("A chicken can be surprisingly fast.", "chicken"),
    ("We watched the chicken chase after bugs.", "chicken"),
    ("He carried the chicken gently under his arm.", "chicken"),
    ("The chicken pecked at the seeds on the ground.", "chicken"),
    ("A mother chicken protects her chicks fiercely.", "chicken"),
    ("They built a fence to keep the chicken safe.", "chicken"),
    ("Our chicken loves to roam in the yard.", "chicken"),
    ("She heard the chicken clucking at sunrise.", "chicken"),
    ("A chicken might eat small pebbles for digestion.", "chicken"),
    ("He decided to adopt a rescued chicken.", "chicken"),
    ("We named our chicken Ruby.", "chicken"),
    ("The chicken strutted around the coop confidently.", "chicken"),
    ("A startled chicken flapped its wings.", "chicken"),
    ("He had to chase the chicken back into its pen.", "chicken"),
    ("She gently petted the chicken on its back.", "chicken"),
    ("A chicken can recognize up to 100 faces.", "chicken"),
    ("We built a new nesting box for our chicken.", "chicken"),
    ("That chicken seems to be the alpha of the flock.", "chicken"),
    ("We watched the chicken taking a dust bath.", "chicken"),
    ("He discovered the chicken had laid five eggs.", "chicken"),
    ("The chicken hopped onto the windowsill.", "chicken"),
    ("A free-range chicken can be healthier.", "chicken"),
    ("We found a lost chicken wandering the street.", "chicken"),
    ("He was crowed at by a rooster, not a chicken.", "chicken"),
    ("The chicken ate grains from my hand.", "chicken"),
    ("She keeps a chicken as a therapy animal.", "chicken"),
    ("The chicken was surprisingly friendly.", "chicken"),
    ("We added new bedding to the chicken coop.", "chicken"),
    ("He painted the chicken coop bright red.", "chicken"),
    ("A chicken is a common farm animal.", "chicken"),
    ("We hatched a chicken from an incubator.", "chicken"),
    ("The chicken made soft clucking sounds in the afternoon.", "chicken"),
    ("She placed a feeder inside the chicken coop.", "chicken"),
    ("The chicken squawked loudly at dusk.", "chicken"),
    ("We found the chicken perched on a fence post.", "chicken"),
    ("A chicken usually roosts at night.", "chicken"),
    ("He introduced a new chicken to the flock.", "chicken"),
    ("Our chicken enjoys sunbathing in the yard.", "chicken"),
    ("She sang a lullaby to calm the chicken.", "chicken"),
    ("A chicken with bright plumage can be quite striking.", "chicken"),
    ("He was amazed that the chicken followed him around.", "chicken"),
    ("We discovered an egg hidden by the chicken.", "chicken"),
    ("The chicken fluffed its feathers in the cold.", "chicken"),
    ("She taught the chicken to come when called.", "chicken"),
    ("He took the chicken to the vet for a check-up.", "chicken"),
    ("A chicken can live several years if well-cared for.", "chicken"),
    ("We heard the chicken scuttling around at night.", "chicken"),
    ("She raised a chicken from a tiny chick.", "chicken"),
    ("The chicken pecked at the window, wanting to come in.", "chicken"),
    ("He picked up the chicken to move it to the coop.", "chicken"),
    ("The chicken seemed curious about the cat.", "chicken"),
    ("We watched the chicken scratch the dirt for worms.", "chicken"),
    ("She built a small ramp for the chicken coop entrance.", "chicken"),
    ("That chicken is molting and losing old feathers.", "chicken"),
    ("He discovered that the chicken prefers certain grains.", "chicken"),
    ("She used leftover vegetables to feed the chicken.", "chicken"),
    ("We worried when the chicken stopped laying eggs.", "chicken"),
    ("The chicken gave a loud squawk when startled.", "chicken"),
    ("He found the chicken hiding in a bush.", "chicken"),
    ("She carefully clipped the chicken's wings to prevent escaping.", "chicken"),
    ("We appreciate the fresh eggs from our chicken.", "chicken"),
    ("The chicken's comb turned bright red.", "chicken"),
    ("He noticed the chicken was limping slightly.", "chicken"),
    ("She tried to teach the chicken a simple trick.", "chicken"),
    ("We heard the chicken rustling around in the straw.", "chicken"),
    ("A new predator might threaten the chicken coop.", "chicken"),
    ("He placed a heat lamp in the coop for the chicken.", "chicken"),
    ("We saw the chicken roosting with the others.", "chicken"),
    ("She hammered some new roosting bars for the chicken.", "chicken"),
    ("He laughed at the chicken's funny noises.", "chicken"),
    ("The chicken's egg had a soft shell, indicating a calcium deficiency.", "chicken"),
    ("She gave the chicken a special treat of mealworms.", "chicken"),
    ("We learned that the chicken prefers a quiet environment.", "chicken"),
    ("He found the chicken exploring the garage.", "chicken"),
    ("Our chicken lays eggs with light brown shells.", "chicken"),
    ("She realized the chicken was missing a few feathers.", "chicken"),
    ("He discovered the chicken dust-bathing in the flowerbed.", "chicken"),
    ("We separated the chicken from the flock to recover.", "chicken"),
    ("She built a small enclosure for the new chicken chicks.", "chicken"),
    ("He used straw to insulate the chicken coop in winter.", "chicken"),
    ("We saw the chicken roosting on a wooden beam.", "chicken"),
    ("She checked the chicken for mites or lice.", "chicken"),
    ("He keeps track of how many eggs each chicken lays.", "chicken"),
    ("A chicken can be quite vocal when laying eggs.", "chicken"),
    ("We found the chicken perched on the roof of the coop.", "chicken"),
    ("She realized the chicken needed more fresh water.", "chicken"),
    ("He gently picked up the chicken to examine its feet.", "chicken"),
    ("The chicken roamed freely until sundown.", "chicken"),
    ("She admired the chicken's glossy feathers.", "chicken"),
    ("He gently placed the chicken back into the coop.", "chicken"),

    # ------------------ CAT (100) ------------------
    ("I saw a cat sleeping on the windowsill.", "cat"),
    ("My cat loves to chase laser pointers.", "cat"),
    ("A stray cat wandered into our backyard.", "cat"),
    ("The cat purred loudly when I pet it.", "cat"),
    ("She adopted a black cat from the shelter.", "cat"),
    ("The cat climbed to the top of the bookshelf.", "cat"),
    ("I heard the cat meowing at the door.", "cat"),
    ("A cat can see well in low light.", "cat"),
    ("He played with the cat using a feather toy.", "cat"),
    ("The cat stretched and yawned lazily.", "cat"),
    ("My neighbor's cat stares at me from the fence.", "cat"),
    ("A cat can be very independent.", "cat"),
    ("She keeps her cat indoors to keep it safe.", "cat"),
    ("The cat knocked over a glass of water.", "cat"),
    ("He brushed the cat's fur to remove tangles.", "cat"),
    ("The cat chased a mouse across the floor.", "cat"),
    ("My friend has a cat named Whiskers.", "cat"),
    ("The cat hissed at the dog next door.", "cat"),
    ("She took her cat to the vet for a check-up.", "cat"),
    ("A cat often naps multiple times a day.", "cat"),
    ("The cat scratched the couch with its claws.", "cat"),
    ("He rewarded the cat with treats for good behavior.", "cat"),
    ("A cat sometimes prefers to stay hidden.", "cat"),
    ("She found a cat napping in a sunny spot.", "cat"),
    ("The cat snuck outside when the door was open.", "cat"),
    ("He heard the cat purring softly on his lap.", "cat"),
    ("A cat can land on its feet thanks to a righting reflex.", "cat"),
    ("She fed the cat wet food every evening.", "cat"),
    ("The cat stared intently at the bird outside.", "cat"),
    ("He discovered the cat sleeping in his laundry basket.", "cat"),
    ("My sister's cat likes to drink from the faucet.", "cat"),
    ("The cat rubbed against my leg for attention.", "cat"),
    ("He took a funny photo of the cat wearing a hat.", "cat"),
    ("A cat can sharpen its claws on a scratching post.", "cat"),
    ("She found a cat collar with a tiny bell.", "cat"),
    ("The cat blinked slowly to show affection.", "cat"),
    ("He called the cat, but it ignored him.", "cat"),
    ("The cat curled up on the sofa next to me.", "cat"),
    ("A cat can hear very high-frequency sounds.", "cat"),
    ("She adopted a stray cat that appeared on her doorstep.", "cat"),
    ("He noticed the cat had unusual markings on its fur.", "cat"),
    ("The cat grew curious about the new puppy.", "cat"),
    ("She left a toy mouse for the cat to play with.", "cat"),
    ("The cat dozed off in the warm sunlight.", "cat"),
    ("He discovered the cat perched on the refrigerator.", "cat"),
    ("A cat can be both aloof and affectionate.", "cat"),
    ("She placed a name tag on her cat's collar.", "cat"),
    ("He installed a cat flap in the back door.", "cat"),
    ("The cat jumped onto the table during dinner.", "cat"),
    ("She spoke softly to calm the anxious cat.", "cat"),
    ("He teased the cat with a dangling string.", "cat"),
    ("A cat's whiskers help it gauge space.", "cat"),
    ("She fosters a rescue cat until it finds a home.", "cat"),
    ("The cat meowed insistently for food.", "cat"),
    ("He found the cat napping in a cardboard box.", "cat"),
    ("The cat swatted at the curtains while playing.", "cat"),
    ("She used treats to teach the cat basic commands.", "cat"),
    ("The cat retreated under the bed when visitors arrived.", "cat"),
    ("He noticed the cat was shedding a lot of fur.", "cat"),
    ("A cat can run quickly in short bursts.", "cat"),
    ("She watched the cat carefully to see its behavior.", "cat"),
    ("He discovered his cat loved chasing crumpled paper.", "cat"),
    ("The cat pawed at the fish tank curiously.", "cat"),
    ("She used a special comb to remove the cat's loose hair.", "cat"),
    ("He found the cat purring beside him on the couch.", "cat"),
    ("A cat sometimes kneads blankets with its paws.", "cat"),
    ("She kept the cat entertained with a puzzle feeder.", "cat"),
    ("The cat jumped at the sound of thunder.", "cat"),
    ("He built a cozy cat bed near the radiator.", "cat"),
    ("The cat licked its paws after finishing a meal.", "cat"),
    ("She had to coax the cat into its carrier.", "cat"),
    ("The cat ran off when it heard a vacuum cleaner.", "cat"),
    ("He put a bell on the cat's collar so he could locate it.", "cat"),
    ("A cat can be highly curious about new smells.", "cat"),
    ("She giggled at the cat's silly antics.", "cat"),
    ("He admired the cat's striking green eyes.", "cat"),
    ("The cat spat out a furball on the rug.", "cat"),
    ("She realized the cat was in heat.", "cat"),
    ("He found his cat sleeping on a pile of clean laundry.", "cat"),
    ("A cat might lick you to show affection.", "cat"),
    ("She gave her cat a new scratching post.", "cat"),
    ("He discovered the cat prowling around the yard at dawn.", "cat"),
    ("The cat let out a soft purr when petted.", "cat"),
    ("She posted pictures of her cat on social media.", "cat"),
    ("He placed the cat's food dish away from its litter box.", "cat"),
    ("The cat silently watched birds through the window.", "cat"),
    ("She taught the cat to sit for a treat.", "cat"),
    ("He noticed the cat was limping and took it to the vet.", "cat"),
    ("The cat rubbed its face against the chair leg.", "cat"),
    ("She gave the cat a bath, which it hated.", "cat"),
    ("He found the cat dozing on his laptop keyboard.", "cat"),
    ("A cat's reflexes are incredibly quick.", "cat"),
    ("She realized the cat was missing and searched everywhere.", "cat"),
    ("He used a laser pointer to exercise the cat.", "cat"),
    ("The cat turned its nose up at the new food.", "cat"),
    ("She gently trimmed the cat's nails.", "cat"),
    ("He noticed the cat's tail twitching in annoyance.", "cat"),
    ("The cat followed him around the house meowing.", "cat"),
    ("She set up a cat tree near a sunny window.", "cat"),
    ("He discovered the cat has a favorite toy mouse.", "cat"),

    # ------------------ COW (100) ------------------
    ("We saw a cow grazing in the pasture.", "cow"),
    ("A cow produces milk that we drink.", "cow"),
    ("He heard a cow mooing loudly at dawn.", "cow"),
    ("The cow wandered near the fence looking for food.", "cow"),
    ("They keep a cow to provide fresh dairy.", "cow"),
    ("A cow can weigh more than a thousand pounds.", "cow"),
    ("She petted the cow gently on its head.", "cow"),
    ("The cow was chewing on some hay in the barn.", "cow"),
    ("He helped deliver a newborn calf from the cow.", "cow"),
    ("We saw the cow walking slowly across the field.", "cow"),
    ("That cow has distinct black and white spots.", "cow"),
    ("She learned how to milk a cow at the farm.", "cow"),
    ("The cow flicked its tail to shoo away flies.", "cow"),
    ("He admired the cow's calm demeanor.", "cow"),
    ("We heard the cow's moo echo across the valley.", "cow"),
    ("A dairy cow typically produces milk daily.", "cow"),
    ("They brought the cow in for the evening feeding.", "cow"),
    ("She found the cow resting under a big tree.", "cow"),
    ("The cow's udder was full, ready for milking.", "cow"),
    ("He guided the cow into the milking parlor.", "cow"),
    ("A cow can live for around 20 years.", "cow"),
    ("She saw the cow chewing cud in a relaxed state.", "cow"),
    ("He named his favorite cow Daisy.", "cow"),
    ("The cow grazed alongside the horses in the field.", "cow"),
    ("We visited a farm to see how a cow is cared for.", "cow"),
    ("He took a photo of the cow standing in the sunset.", "cow"),
    ("That cow produces a large quantity of milk.", "cow"),
    ("She guided the cow with gentle taps on its side.", "cow"),
    ("He tested the cow's milk for quality.", "cow"),
    ("We noticed the cow had a bell around its neck.", "cow"),
    ("The cow bellowed when it was separated from the herd.", "cow"),
    ("She cleaned the cow's stall every morning.", "cow"),
    ("He pointed out that the cow had a calf with her.", "cow"),
    ("A cow's diet mostly consists of grass and hay.", "cow"),
    ("We saw a herd with more than one cow grazing by a lake.", "cow"),
    ("She learned about the different breeds of cow at school.", "cow"),
    ("He tried to move the cow, but it wouldn't budge.", "cow"),
    ("The farmer brought the cow fresh water.", "cow"),
    ("She noticed that the cow was limping slightly.", "cow"),
    ("A baby cow is called a calf.", "cow"),
    ("He watched the cow munch on fresh grass.", "cow"),
    ("We realized the cow needed a veterinarian's help.", "cow"),
    ("She heard a soft moo from the cow in the corner.", "cow"),
    ("He had to herd the cow back into the pen.", "cow"),
    ("A cow is a common sight in rural areas.", "cow"),
    ("We feed the cow special grains for better milk production.", "cow"),
    ("She saw the cow rolling in the grass.", "cow"),
    ("He measured how much milk the cow produced.", "cow"),
    ("The cow stared at us with large, curious eyes.", "cow"),
    ("We let the cow roam freely in the meadow.", "cow"),
    ("She brushed the cow's coat to keep it clean.", "cow"),
    ("He was wary of approaching a protective cow with a calf.", "cow"),
    ("A cow can recognize the faces of other cows.", "cow"),
    ("We followed the footprints the cow left in the mud.", "cow"),
    ("She gave the cow a gentle pat on its flank.", "cow"),
    ("He taught his son how to milk a cow by hand.", "cow"),
    ("The cow sniffed at the bucket of feed.", "cow"),
    ("We found the cow lying comfortably in the shade.", "cow"),
    ("She discovered the cow was pregnant again.", "cow"),
    ("He tried to lead the cow with a rope halter.", "cow"),
    ("A group of cows is called a herd, but we have one cow here.", "cow"),
    ("We enjoyed watching the cow laze around the pasture.", "cow"),
    ("She realized the cow was an older member of the herd.", "cow"),
    ("He had to coax the cow into the trailer.", "cow"),
    ("The cow's gentle mooing was calming.", "cow"),
    ("We kept the cow in a sturdy pen overnight.", "cow"),
    ("She gave the cow a treat of sliced apples.", "cow"),
    ("He recognized the cow was a Holstein breed.", "cow"),
    ("The cow contentedly grazed next to the fence.", "cow"),
    ("We tested the cow for any illnesses.", "cow"),
    ("She wore boots to avoid stepping in cow manure.", "cow"),
    ("He found the cow resting on a bed of straw.", "cow"),
    ("A well-fed cow produces better quality milk.", "cow"),
    ("We saw a cow crossing the road near the farm.", "cow"),
    ("She collected data on the cow's milk yield each day.", "cow"),
    ("He gently tugged on the rope to move the cow.", "cow"),
    ("A cow can sometimes be stubborn.", "cow"),
    ("We gave the cow fresh hay to nibble on.", "cow"),
    ("She was surprised at how friendly the cow was.", "cow"),
    ("He checked the cow's hooves for stones.", "cow"),
    ("The cow's horns were short but still noticeable.", "cow"),
    ("We watched the cow peacefully graze as the sun set.", "cow"),
    ("She found the cow in the wrong pasture.", "cow"),
    ("He called the cow, and it slowly walked toward him.", "cow"),
    ("A healthy cow is essential for a thriving farm.", "cow"),
    ("We placed a tag on the cow's ear for identification.", "cow"),
    ("She trimmed the cow's hooves to keep them healthy.", "cow"),
    ("He was amazed by the cow's large size up close.", "cow"),
    ("The cow let out a deep sound to call its calf.", "cow"),
    ("We saw the cow's breath on a cold morning.", "cow"),
    ("She offered the cow a bucket of water after milking.", "cow"),
    ("He noticed the cow had a small patch of white on its forehead.", "cow"),
    ("A content cow wags its tail slowly.", "cow"),
    ("We added more bedding for the cow to sleep on.", "cow"),
    ("She explained how to read the cow's body language.", "cow"),
    ("He realized the cow had knocked over the feed bucket.", "cow"),
    ("We marveled at how strong the cow was.", "cow"),
    ("She found the cow grazing near the orchard.", "cow"),
    ("He knew the cow needed a vitamin supplement.", "cow"),
    ("We thanked the farmer for letting us see his cow up close.", "cow"),

    # ------------------ SHEEP (100) ------------------
    ("We saw a flock of sheep grazing on the hillside.", "sheep"),
    ("A sheep can provide wool for clothing.", "sheep"),
    ("He heard a sheep bleating early in the morning.", "sheep"),
    ("They sheared the sheep to collect its wool.", "sheep"),
    ("A baby sheep is called a lamb.", "sheep"),
    ("She bottle-fed an orphaned sheep at the farm.", "sheep"),
    ("The sheep wandered away from the flock.", "sheep"),
    ("He guided the sheep through the gate.", "sheep"),
    ("A sheep can recognize a familiar face.", "sheep"),
    ("We watched the sheep munching on fresh grass.", "sheep"),
    ("She petted the sheep gently between its ears.", "sheep"),
    ("The sheep trotted after the shepherd.", "sheep"),
    ("He fenced in the pasture to keep the sheep secure.", "sheep"),
    ("A sheep can be quite timid around strangers.", "sheep"),
    ("We used the wool from the sheep to knit sweaters.", "sheep"),
    ("She found a lost sheep near the river.", "sheep"),
    ("He discovered the sheep had injured its leg.", "sheep"),
    ("A sheep's wool keeps it warm in cold weather.", "sheep"),
    ("They keep a sheep for its milk as well.", "sheep"),
    ("She gently brushed the dirt off the sheep's coat.", "sheep"),
    ("He admired the sheep's thick, curly fleece.", "sheep"),
    ("A guard dog protected the sheep from predators.", "sheep"),
    ("We saw the sheep huddled together in the rain.", "sheep"),
    ("She helped deliver a newborn lamb from the sheep.", "sheep"),
    ("He recognized the sheep breed as Merino.", "sheep"),
    ("A sheep can live for about a decade or more.", "sheep"),
    ("We followed the shepherd guiding his sheep along the road.", "sheep"),
    ("She learned how to spin wool from the sheep's fleece.", "sheep"),
    ("He found the sheep lying down near the fence.", "sheep"),
    ("The sheep stared at us with curious eyes.", "sheep"),
    ("We watched the sheep get vaccinated by the vet.", "sheep"),
    ("She realized the sheep was pregnant.", "sheep"),
    ("He noticed one sheep was lagging behind the others.", "sheep"),
    ("A well-cared-for sheep can produce quality wool.", "sheep"),
    ("We have two dogs to help herd the sheep.", "sheep"),
    ("She gently took a lamb from its mother sheep to weigh it.", "sheep"),
    ("He was amazed at how docile the sheep were.", "sheep"),
    ("We lost count of how many sheep were in the flock.", "sheep"),
    ("She always checks the sheep for signs of illness.", "sheep"),
    ("He found a stray sheep wandering along the highway.", "sheep"),
    ("A sheep's bleat can sound surprisingly loud.", "sheep"),
    ("We carefully guided the sheep into the barn.", "sheep"),
    ("She taught her children how to feed the sheep.", "sheep"),
    ("He placed a bell on the lead sheep to track them.", "sheep"),
    ("The sheep scattered when they heard a loud noise.", "sheep"),
    ("We sold the wool sheared from the sheep.", "sheep"),
    ("She used special shears to remove the sheep's fleece.", "sheep"),
    ("He dyed the wool from the sheep to make yarn.", "sheep"),
    ("A mother sheep licked her newborn lamb clean.", "sheep"),
    ("We saw the sheep nuzzling its lamb affectionately.", "sheep"),
    ("She counted each sheep to make sure none were missing.", "sheep"),
    ("He realized the sheep needed a foot trimming.", "sheep"),
    ("We watched the sheep chewing cud peacefully.", "sheep"),
    ("She provided fresh hay for the sheep to eat.", "sheep"),
    ("He discovered that sheep can remember faces for years.", "sheep"),
    ("The sheep followed the shepherd dog across the meadow.", "sheep"),
    ("She found the sheep resting under a large oak tree.", "sheep"),
    ("He mended the fence to prevent the sheep from escaping.", "sheep"),
    ("A healthy sheep has bright eyes and good appetite.", "sheep"),
    ("We carried the lamb to reunite it with the mother sheep.", "sheep"),
    ("She noticed the sheep's wool was beginning to mat.", "sheep"),
    ("He built a small shelter for the sheep in the field.", "sheep"),
    ("We gently guided the sheep into a new pasture.", "sheep"),
    ("She separated the sick sheep from the rest of the flock.", "sheep"),
    ("He could identify each sheep by its markings.", "sheep"),
    ("We took the sheep to a local agricultural show.", "sheep"),
    ("She found that the sheep responded to her voice.", "sheep"),
    ("He wore a wool hat made from his own sheep's wool.", "sheep"),
    ("We marveled at the sheep's calm demeanor.", "sheep"),
    ("She realized the sheep needed more water on a hot day.", "sheep"),
    ("He discovered the sheep had twin lambs.", "sheep"),
    ("A sheep's diet mainly consists of grass and hay.", "sheep"),
    ("We used straw to create warm bedding for the sheep.", "sheep"),
    ("She massaged the sheep's legs to help it stand.", "sheep"),
    ("He taught his children how to care for a sheep.", "sheep"),
    ("The sheep parted ways to let us pass.", "sheep"),
    ("We observed the sheep grazing along the hillside at sunset.", "sheep"),
    ("She made sure the sheep were locked up safe at night.", "sheep"),
    ("He gently caught a sheep to check its hooves.", "sheep"),
    ("A group of sheep is led by a shepherd or a dog.", "sheep"),
    ("We discovered the sheep had a minor skin infection.", "sheep"),
    ("She told us how the sheep produce lanolin in their wool.", "sheep"),
    ("He used a crook to snag a sheep that was wandering off.", "sheep"),
    ("We combed through the sheep's fleece to remove debris.", "sheep"),
    ("She crocheted a blanket using wool from her sheep.", "sheep"),
    ("He learned that sheep have rectangular pupils.", "sheep"),
    ("We listened to the sheep bleating for their lambs.", "sheep"),
    ("She found a small burr tangled in the sheep's wool.", "sheep"),
    ("He had to calm the sheep before the vet could examine it.", "sheep"),
    ("A watchful dog keeps the sheep from straying.", "sheep"),
    ("We introduced a new sheep to the existing flock.", "sheep"),
    ("She sold the sheep's wool at the local market.", "sheep"),
    ("He felt pride in raising a healthy sheep flock.", "sheep"),
    ("We realized that caring for a sheep requires daily attention.", "sheep"),
    ("She gave the sheep a mineral supplement for better health.", "sheep"),
    ("He saw the sheep crossing a shallow stream.", "sheep"),
    ("A sheepskin rug can be made from the hide of a sheep.", "sheep"),
    ("We let the sheep roam in the orchard to eat fallen fruit.", "sheep"),
    ("She checked the sheep for ticks in its fleece.", "sheep"),
    ("He dozed off counting sheep in his mind.", "sheep"),

    # ------------------ SQUIRREL (100) ------------------
    ("I saw a squirrel climbing up the oak tree.", "squirrel"),
    ("The squirrel chattered loudly when I approached.", "squirrel"),
    ("She left nuts on the porch for the squirrel.", "squirrel"),
    ("A squirrel darted across the road in front of me.", "squirrel"),
    ("We watched the squirrel bury an acorn in the yard.", "squirrel"),
    ("He noticed the squirrel had a thick, bushy tail.", "squirrel"),
    ("A squirrel can leap from branch to branch with ease.", "squirrel"),
    ("She found a baby squirrel lying on the ground.", "squirrel"),
    ("The squirrel scurried along the fence top.", "squirrel"),
    ("He saw the squirrel nibbling on a piece of bread.", "squirrel"),
    ("We heard the squirrel rustling in the leaves.", "squirrel"),
    ("She tried to photograph the squirrel, but it ran away.", "squirrel"),
    ("The squirrel paused to look at us before climbing higher.", "squirrel"),
    ("He built a squirrel feeder to keep them away from birdseed.", "squirrel"),
    ("A squirrel can be quite clever at stealing food.", "squirrel"),
    ("She spotted a black squirrel in the park.", "squirrel"),
    ("He found the squirrel chewing on a plastic toy.", "squirrel"),
    ("We saw the squirrel chasing another squirrel up a tree.", "squirrel"),
    ("The squirrel stuffed its cheeks with seeds.", "squirrel"),
    ("She laughed as the squirrel peeked through the window.", "squirrel"),
    ("He placed a small bowl of water for the squirrel.", "squirrel"),
    ("A squirrel often collects nuts for the winter.", "squirrel"),
    ("She watched the squirrel jump onto the roof.", "squirrel"),
    ("He heard the squirrel scampering in the attic.", "squirrel"),
    ("We admired the squirrel's agility among the branches.", "squirrel"),
    ("She discovered the squirrel's hidden stash of acorns.", "squirrel"),
    ("He gently shooed the squirrel away from the car engine.", "squirrel"),
    ("A squirrel's tail helps it balance on narrow ledges.", "squirrel"),
    ("We noticed the squirrel was missing a patch of fur.", "squirrel"),
    ("She tried to get close to the squirrel, but it was too shy.", "squirrel"),
    ("He saw the squirrel nibbling on sunflower seeds.", "squirrel"),
    ("The squirrel darted into a hole in the tree trunk.", "squirrel"),
    ("She exclaimed as the squirrel nearly jumped onto her shoulder.", "squirrel"),
    ("He found the squirrel rummaging through the trash can.", "squirrel"),
    ("We watched the squirrel meticulously clean its fur.", "squirrel"),
    ("A squirrel can run quickly on fence lines.", "squirrel"),
    ("She left peanuts on the bird feeder for the squirrel.", "squirrel"),
    ("He was startled when the squirrel suddenly appeared.", "squirrel"),
    ("The squirrel hopped across the lawn in quick bursts.", "squirrel"),
    ("She saw the squirrel stash a nut in a flowerpot.", "squirrel"),
    ("He tried to protect his garden from the squirrel.", "squirrel"),
    ("The squirrel scolded us from a high branch.", "squirrel"),
    ("We laughed at the squirrel's playful antics.", "squirrel"),
    ("She carefully observed the squirrel's sharp claws.", "squirrel"),
    ("He discovered the squirrel had chewed through the birdhouse.", "squirrel"),
    ("A squirrel can rotate its ankles to climb down headfirst.", "squirrel"),
    ("She watched the squirrel race along a telephone wire.", "squirrel"),
    ("He found the squirrel sleeping in the crook of a tree.", "squirrel"),
    ("We saw the squirrel pounce on a fallen apple.", "squirrel"),
    ("She admired the squirrel's bushy tail swishing behind it.", "squirrel"),
    ("He placed a squirrel baffle on the bird feeder pole.", "squirrel"),
    ("A squirrel can store hundreds of nuts each season.", "squirrel"),
    ("We encountered a fearless squirrel in the city park.", "squirrel"),
    ("She noticed the squirrel had distinct ear tufts.", "squirrel"),
    ("He realized the squirrel had been nesting in his shed.", "squirrel"),
    ("The squirrel zipped past us as we walked the trail.", "squirrel"),
    ("She giggled watching the squirrel chase a bird away.", "squirrel"),
    ("He named the friendly squirrel that frequented his yard.", "squirrel"),
    ("We heard the squirrel scolding another animal.", "squirrel"),
    ("She scattered seeds on the deck to lure the squirrel.", "squirrel"),
    ("He got a photo of the squirrel standing on its hind legs.", "squirrel"),
    ("A squirrel's teeth never stop growing.", "squirrel"),
    ("We saw the squirrel run across the street safely.", "squirrel"),
    ("She marveled at the squirrel's acrobatic feats.", "squirrel"),
    ("He tried to catch the squirrel in a live trap but failed.", "squirrel"),
    ("The squirrel quickly vanished into the foliage.", "squirrel"),
    ("She recognized the squirrel by its unique coloring.", "squirrel"),
    ("He found an abandoned squirrel nest in the yard.", "squirrel"),
    ("We saw the squirrel leap an impressive distance.", "squirrel"),
    ("She coaxed the squirrel closer with a peanut.", "squirrel"),
    ("He realized the squirrel had gnawed on the windowsill.", "squirrel"),
    ("A squirrel can become quite tame with regular feeding.", "squirrel"),
    ("We watched the squirrel chase its tail briefly.", "squirrel"),
    ("She found the squirrel hiding under the car.", "squirrel"),
    ("He set up a camera to watch the squirrel's nighttime activities.", "squirrel"),
    ("The squirrel squeaked when cornered by a cat.", "squirrel"),
    ("She rescued a baby squirrel and took it to a wildlife center.", "squirrel"),
    ("He discovered the squirrel hoarded acorns in his boots.", "squirrel"),
    ("We laughed as the squirrel raced along the picnic table.", "squirrel"),
    ("She admired the squirrel's quick reflexes.", "squirrel"),
    ("He had to seal the attic to keep the squirrel out.", "squirrel"),
    ("The squirrel was perched on the telephone pole.", "squirrel"),
    ("She fed the squirrel a piece of walnut from her hand.", "squirrel"),
    ("He observed the squirrel chewing on a twig.", "squirrel"),
    ("We heard the squirrel's rapid chatter echo in the trees.", "squirrel"),
    ("She saw the squirrel slip into a crack in the fence.", "squirrel"),
    ("He tried to get a closer look, but the squirrel fled.", "squirrel"),
    ("A squirrel often flicks its tail to communicate.", "squirrel"),
    ("We noticed the squirrel had a distinctive white patch on its chest.", "squirrel"),
    ("She put a sign up: 'Do not feed the squirrel' after it became a pest.", "squirrel"),
    ("He found the squirrel nibbling on leftover pizza crust.", "squirrel"),
    ("The squirrel perched on a low branch, watching us.", "squirrel"),
    ("She discovered a family of squirrel pups in the yard.", "squirrel"),
    ("He startled the squirrel, and it ran up his leg briefly.", "squirrel"),
    ("We saw the squirrel rummaging through fallen leaves.", "squirrel"),
    ("She worried the squirrel might get into the attic again.", "squirrel"),
    ("He banged on the window to scare the squirrel away from the feeder.", "squirrel"),
    ("The squirrel hopped onto a nearby tree stump.", "squirrel"),
    ("She attempted to distract the squirrel while retrieving the seeds.", "squirrel"),
    ("He watched the squirrel dash up the tree with an acorn in its mouth.", "squirrel"),

    # ------------------ SPIDER (100) ------------------
    ("A spider spun a web in the corner of the window.", "spider"),
    ("She found a spider crawling on the kitchen floor.", "spider"),
    ("He carefully relocated the spider outside.", "spider"),
    ("The spider dangled from the ceiling by a thin thread.", "spider"),
    ("We watched the spider wrapping its prey in silk.", "spider"),
    ("A spider's web glistened with morning dew.", "spider"),
    ("She noticed the spider had bright yellow stripes.", "spider"),
    ("He discovered a spider nest in the shed.", "spider"),
    ("A spider can have eight eyes, depending on the species.", "spider"),
    ("We saw the spider quickly scuttle under the couch.", "spider"),
    ("She tried not to disturb the spider building its web.", "spider"),
    ("He was startled when the spider dropped onto the table.", "spider"),
    ("A spider might help keep insect populations under control.", "spider"),
    ("We admired the spider's intricate web design.", "spider"),
    ("She observed the spider patiently waiting in the center of its web.", "spider"),
    ("He gently blew on the spider to see if it would move.", "spider"),
    ("A spider can produce different types of silk.", "spider"),
    ("We found a spider egg sac attached to the wall.", "spider"),
    ("She got rid of the cobwebs but left the spider unharmed.", "spider"),
    ("He identified the spider as a harmless house spider.", "spider"),
    ("A spider can sense vibrations through its web.", "spider"),
    ("We noticed the spider's web spanned several feet.", "spider"),
    ("She discovered a jumping spider on her window sill.", "spider"),
    ("He carefully trapped the spider in a cup to release it outside.", "spider"),
    ("The spider's long legs helped it move swiftly.", "spider"),
    ("We saw the spider climbing up a water spout.", "spider"),
    ("She marveled at the spider's ability to hang upside down.", "spider"),
    ("He used a flashlight to spot the spider in the dark corner.", "spider"),
    ("A spider hunts using stealth and patience.", "spider"),
    ("We realized the spider had caught a moth in its web.", "spider"),
    ("She tried to identify the spider species online.", "spider"),
    ("He encountered a large spider while cleaning the basement.", "spider"),
    ("The spider slowly descended on a single strand of silk.", "spider"),
    ("We watched the spider scurry away when we approached.", "spider"),
    ("She found a bright green spider on a leaf.", "spider"),
    ("He was relieved to learn that the spider was not poisonous.", "spider"),
    ("A spider's silk is stronger than steel of the same thickness.", "spider"),
    ("We counted eight legs on the spider, confirming its identity.", "spider"),
    ("She discovered the spider near the garden shed.", "spider"),
    ("He saw the spider leap a short distance to catch prey.", "spider"),
    ("A spider can shed its exoskeleton as it grows.", "spider"),
    ("We used a piece of paper to gently move the spider.", "spider"),
    ("She let the spider remain in the corner to eat mosquitoes.", "spider"),
    ("He found a tiny spider spinning a web around a lamp.", "spider"),
    ("We saw the spider's silhouette against the setting sun.", "spider"),
    ("She squealed when the spider crawled onto her hand by accident.", "spider"),
    ("He placed the spider in a safe spot away from the door.", "spider"),
    ("A spider can lay hundreds of eggs in a sac.", "spider"),
    ("We carefully observed the spider's unique markings.", "spider"),
    ("She realized the spider was missing a leg.", "spider"),
    ("He used a macro lens to photograph the spider up close.", "spider"),
    ("The spider quickly repaired a damaged section of its web.", "spider"),
    ("She tried to remain calm around the large spider.", "spider"),
    ("He recalled that the spider can be a helpful houseguest by eating pests.", "spider"),
    ("A spider can bite if it feels threatened.", "spider"),
    ("We watched as the spider pulled strands of silk to shape its web.", "spider"),
    ("She discovered a spider on her shoulder and brushed it off gently.", "spider"),
    ("He saw a tarantula, a large and hairy spider, at the pet store.", "spider"),
    ("The spider retreated into a crevice when the light shone on it.", "spider"),
    ("We recognized the spider as a garden orb weaver.", "spider"),
    ("She was fascinated by the spider's rapid weaving skill.", "spider"),
    ("He carefully avoided stepping on the tiny spider.", "spider"),
    ("A spider has specialized glands to produce silk.", "spider"),
    ("We observed the spider's fangs as it captured an insect.", "spider"),
    ("She left the basement spider alone to reduce the bug population.", "spider"),
    ("He named the small spider living in his window corner.", "spider"),
    ("The spider remained motionless, waiting for prey.", "spider"),
    ("We found a spider weaving a web near the porch light.", "spider"),
    ("She learned that some spider species care for their young.", "spider"),
    ("He placed a piece of paper under the spider to move it outside.", "spider"),
    ("A spider's sense of touch is very keen.", "spider"),
    ("We discovered a spider web connecting two branches.", "spider"),
    ("She hesitantly watched the spider crawl near her seat.", "spider"),
    ("He shined a light under the couch and saw multiple spider webs.", "spider"),
    ("The spider quickly retreated when we tried to catch it.", "spider"),
    ("We realized the spider had captured a small fly in its web.", "spider"),
    ("She overcame her fear by learning about the spider's role in nature.", "spider"),
    ("He gently removed the spider and set it on a plant outside.", "spider"),
    ("A spider's venom can immobilize its prey.", "spider"),
    ("We noticed the spider's eyes reflecting the flashlight beam.", "spider"),
    ("She researched spider species common to her area.", "spider"),
    ("He admired the spider's ability to spin silk in various patterns.", "spider"),
    ("The spider anchored its web to the fence post.", "spider"),
    ("We found the spider's old exoskeleton hanging by the web.", "spider"),
    ("She thought the spider's camouflage was impressive.", "spider"),
    ("He worried that the spider might be venomous, but it wasn't.", "spider"),
    ("A spider can rebuild a destroyed web overnight.", "spider"),
    ("We carefully watched the spider drop onto a leaf.", "spider"),
    ("She took a close-up picture of the spider's intricate markings.", "spider"),
    ("He saw a spider scurry away with a tiny insect in its jaws.", "spider"),
    ("The spider expanded its web after catching several insects.", "spider"),
    ("We realized the spider was actually quite small once we got closer.", "spider"),
    ("She gently relocated the spider from the sink to the garden.", "spider"),
    ("He used a jar to scoop up the spider from the windowsill.", "spider"),
    ("A spider's body is divided into the cephalothorax and abdomen.", "spider"),
    ("We spotted a spider creeping along the bathroom wall.", "spider"),
    ("She carefully avoided damaging the spider's new web.", "spider"),
    ("He described the spider as fuzzy with striped legs.", "spider"),
    ("We discovered a mother spider carrying her babies on her back.", "spider"),
    ("She let the spider remain in the garden to catch pests.", "spider"),
]

# %%
folder_name = "data/trans"
name_csv = "text-animals.csv"

if not os.path.exists(folder_name):
    os.makedirs(folder_name)

file_path = os.path.join(folder_name, name_csv)

if not os.path.exists(file_path):
    with open(file_path, "w", encoding="utf-8", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["text", "label"])
        for text, label in data:
            writer.writerow([text, label])
    print(f"CSV-file {name_csv} successfully created!")
else:
    print(f"CSV-file {name_csv} has already been created!")
# Out:
# CSV-file text-animals.csv successfully created!
